# %%
from selenium import webdriver
from selenium.webdriver.common.by import By
from selenium.webdriver.chrome.service import Service
from selenium.webdriver.common.keys import Keys
import time
import bs4,requests,os

# 用selenium找到頁面
url='https://udn.com/news/index'
driver_path=Service('D:/chromedriver.exe')
driver=webdriver.Chrome(service=driver_path)
driver.get(url)
driver.find_element(By.CLASS_NAME,'menu-toggler').click()
# 透過css找到搜尋鍵並按下
find_what=driver.find_element(By.CSS_SELECTOR,"div.input-holder input[type='search']")
find_what.send_keys('七星山')  # 送出要搜尋的字串
time.sleep(3)
driver.find_element(By.CLASS_NAME,'btn-search').click()
url_1=driver.current_url  # 找到點入的網址
print(url_1)
time.sleep(3)
# driver.close()
# Out:
# https://udn.com/search/word/2/%E4%B8%83%E6%98%9F%E5%B1%B1

# %%
from selenium import webdriver
from selenium.webdriver.common.by import By
from selenium.webdriver.chrome.service import Service
from selenium.webdriver.common.keys import Keys
import time
import bs4,requests,os,csv
import pandas as pd

# 用selenium找到頁面
url='https://udn.com/search/word/2/%E9%BA%A5%E7%95%B6%E5%8B%9E'
driver_path=Service('D:/chromedriver.exe')
driver=webdriver.Chrome(service=driver_path)
driver.get(url)

# 用bs4找出共幾頁
html=requests.get(url_1)
obj=bs4.BeautifulSoup(html.text,'lxml')

total_num=obj.find('div','search-total').span.text.strip()
total_num=int(int(total_num)/20)
print(total_num)

count_num=0  # 紀錄滑了幾次
add_num=100  # 卷軸要滑的距離

# 執行次數至網頁完全載入 才能一次存爬取內容
for top in range(total_num):
    use_keys=driver.find_element(By.TAG_NAME,'body')
    time.sleep(4)
    count_num+=1
    print('第 %s 次' % count_num)
    add_num+=20  # 因為卷軸會越來越長
    
    # 讓卷軸不段滑的for
    for down in range(0,add_num,2):
        use_keys.send_keys(Keys.PAGE_DOWN)  # 往下快快滑到底 讓網頁動態加載
    time.sleep(1)
    use_keys.send_keys(Keys.HOME)   # 再直接滑到最頂
    new_pega=driver.page_source    # 重新抓取加載後的網頁內容
    new_obj=bs4.BeautifulSoup(new_pega,'lxml')     # 轉成bs4
    
#print(new_obj)
# time.sleep(5)
org_divs=obj.find('div','story-list__holder').find_all('div','story-list__news')
# pp=obj.find('div','story-list__holder').find('section','story-list__holder--append') #.find_all('div','story-list__news  ')
print('原本就在的文章數:',len(org_divs))
new_divs=new_obj.find('div','story-list__holder').find('section','story-list__holder--append').find_all('div','story-list__news')
print('動態加載後文章數:',len(new_divs))

txt_list=[]  # 給需要的文字內容建成表格用
photo_list=[]   # 給圖片用
photo_Dir='find_McDonalds_1'
if os.path.exists(photo_Dir)==False:
     os.mkdir(photo_Dir)

# 原本就在的文章
for org in org_divs:
    s=org.find('div','story-list__text')
    title=s.h2.text.strip()
    date=s.find('time','story-list__time').text.strip()
    content=s.p.text.strip()
    photo_src=org.find('div','story-list__image').img['data-src']
        
    print('標題:',title)
    print('日期:',date)
    print('內文:',content)  
    print('圖片連結:',photo_src)
    print()
    txt_list.append([title,date,content,photo_src])
    photo_list.append(photo_src)
    
print(len(txt_list))    
print(len(photo_list))
print('-'*70)

# 動態加載後的文章
for new in new_divs:
    n=new.find('div','story-list__text')
    title=n.h2.text.strip()
    date=n.find('time','story-list__time').text.strip()
    content=n.p.text.strip()
    photo_src=new.find('div','story-list__image').img['data-src']
        
    print('標題:',title)
    print('日期:',date)
    print('內文:',content)
    print('圖片連結:',photo_src)
    print()
    txt_list.append([title,date,content,photo_src])
    photo_list.append(photo_src)  
    
# 把需要的文字內容存成csv
print(txt_list)
txt_df=pd.DataFrame(txt_list,columns=['標題','日期','內文','圖片網址'])
print(txt_df)
txt_df.to_csv('find_McDonalds_1.csv')

#下載圖片並存檔
print(len(photo_list)) 
for photo in photo_list:
    photo_name=os.path.basename(photo).split('.')[0]+str('.jpg')
    print(photo_name)
    try:
        load_photo=requests.get(photo)
        load_photo.raise_for_status()
        print('圖片下載成功')
        photo_file=open(os.path.join(photo_Dir,photo_name),'wb')
        for l in load_photo.iter_content(10240):
            photo_file.write(l)
    except Exception as err:
        print('圖片下載失敗')
print('---所有圖片下載完成---')
    
driver.close()
# Out:
# 14
# ---------------------------------------------------------------------------
# NoSuchWindowException                     Traceback (most recent call last)
# ~\AppData\Local\Temp/ipykernel_8628/1666609526.py in <module>
#      26 # 執行次數至網頁完全載入 才能一次存爬取內容
#      27 for top in range(total_num):
# ---> 28     use_keys=driver.find_element(By.TAG_NAME,'body')
#      29     time.sleep(4)
#      30     count_num+=1
#
# ~\anaconda3\envs\LuvPython\lib\site-packages\selenium\webdriver\remote\webdriver.py in find_element(self, by, value)
#    1246             value = '[name="%s"]' % value
#    1247
# -> 1248         return self.execute(Command.FIND_ELEMENT, {
#    1249             'using': by,
#    1250             'value': value})['value']
#
# ~\anaconda3\envs\LuvPython\lib\site-packages\selenium\webdriver\remote\webdriver.py in execute(self, driver_command, params)
#     423         response = self.command_executor.execute(driver_command, params)
#     424         if response:
# --> 425             self.error_handler.check_response(response)
#     426             response['value'] = self._unwrap_value(
#     427                 response.get('value', None))
#
# ~\anaconda3\envs\LuvPython\lib\site-packages\selenium\webdriver\remote\errorhandler.py in check_response(self, response)
#     245                 alert_text = value['alert'].get('text')
#     246             raise exception_class(message, screen, stacktrace, alert_text)  # type: ignore[call-arg]  # mypy is not smart enough here
# --> 247         raise exception_class(message, screen, stacktrace)
#     248
#     249     def _value_or_default(self, obj: Mapping[_KT, _VT], key: _KT, default: _VT) -> _VT:
#
# NoSuchWindowException: Message: no such window: target window already closed
# from unknown error: web view not found
#   (Session info: chrome=100.0.4896.127)
# Stacktrace:
# Backtrace:
# 	Ordinal0 [0x01217413+2389011]
# 	Ordinal0 [0x011A9F61+1941345]
# 	Ordinal0 [0x0109C658+837208]
# 	Ordinal0 [0x01084480+738432]
# 	Ordinal0 [0x010E6999+1141145]
# 	Ordinal0 [0x010F3AA2+1194658]
# 	Ordinal0 [0x010E3F66+1130342]
# 	Ordinal0 [0x010BE546+976198]
# 	Ordinal0 [0x010BF456+980054]
# 	GetHandleVerifier [0x013C9632+1727522]
# 	GetHandleVerifier [0x0147BA4D+2457661]
# 	GetHandleVerifier [0x012AEB81+569713]
# 	GetHandleVerifier [0x012ADD76+566118]
# 	Ordinal0 [0x011B0B2B+1968939]
# 	Ordinal0 [0x011B5988+1989000]
# 	Ordinal0 [0x011B5A75+1989237]
# 	Ordinal0 [0x011BECB1+2026673]
# 	BaseThreadInitThunk [0x7606FA29+25]
# 	RtlGetAppContainerNamedObjectPath [0x772E7A7E+286]
# 	RtlGetAppContainerNamedObjectPath [0x772E7A4E+238]

# %%
# 因為是動態加載的網頁 所以先把全部網頁內容都載完 再用pandas一次寫入csv
from selenium import webdriver
from selenium.webdriver.common.by import By
from selenium.webdriver.chrome.service import Service
from selenium.webdriver.common.keys import Keys
import time
import bs4,requests,os,csv
import pandas as pd

input_=input('請輸入想查詢的關鍵字:')
#input_='陳彥博'

# 用selenium找到頁面
url='https://udn.com/news/index'
driver_path=Service('D:/chromedriver.exe')
driver=webdriver.Chrome(service=driver_path)
driver.get(url)
driver.find_element(By.CLASS_NAME,'menu-toggler').click()
# 透過css找到搜尋鍵並按下
find_what=driver.find_element(By.CSS_SELECTOR,"div.input-holder input[type='search']")
find_what.send_keys(input_)  # 送出要搜尋的字串
time.sleep(3)
driver.find_element(By.CLASS_NAME,'btn-search').click()
url_1=driver.current_url  # 找到點入的網址
print(url_1)
time.sleep(3)

# 用bs4找出共幾頁
html=requests.get(url_1)
obj=bs4.BeautifulSoup(html.text,'lxml')

total_num=obj.find('div','search-total').span.text.strip()
total_num=int(int(total_num)/20)
print(total_num)

count_num=0  # 紀錄滑了幾次
add_num=100  # 卷軸要滑的距離

# 執行次數至網頁完全載入 才能一次存爬取內容
for top in range(total_num):
    use_keys=driver.find_element(By.TAG_NAME,'body')
    time.sleep(5)
    count_num+=1
    print('第 %s 次' % count_num)
    add_num+=20  # 因為卷軸會越來越長
    
    # 讓卷軸不段滑的for
    for down in range(0,add_num,2):
        use_keys.send_keys(Keys.PAGE_DOWN)  # 往下快快滑到底 讓網頁動態加載
    time.sleep(5)
    use_keys.send_keys(Keys.HOME)   # 再直接滑到最頂
    new_pega=driver.page_source    # 重新抓取加載後的網頁內容
    new_obj=bs4.BeautifulSoup(new_pega,'lxml')     # 轉成bs4
    
#print(new_obj)
# time.sleep(5)
org_divs=obj.find('div','story-list__holder').find_all('div','story-list__news')
# pp=obj.find('div','story-list__holder').find('section','story-list__holder--append') #.find_all('div','story-list__news  ')
print('原本就在的文章數:',len(org_divs))
new_divs=new_obj.find('div','story-list__holder').find('section','story-list__holder--append').find_all('div','story-list__news')
print('動態加載後文章數:',len(new_divs))

txt_list=[]  # 給需要的文字內容建成表格用
photo_list=[]   # 給圖片用
photo_dir='find_'+input_+'_1'
if os.path.exists(photo_dir)==False:
     os.mkdir(photo_dir)

# 原本就在的文章
for org in org_divs:
    s=org.find('div','story-list__text')
    title=s.h2.text.strip()
    date=s.find('time','story-list__time').text.strip()
    content=s.p.text.strip()
    photo_src=org.find('div','story-list__image').img['data-src']
        
    print('標題:',title)
    print('日期:',date)
    print('內文:',content)  
    print('圖片連結:',photo_src)
    print()
    txt_list.append([title,date,content,photo_src])
    photo_list.append(photo_src)
    
print(len(txt_list))    
print(len(photo_list))
print('-'*70)

# 動態加載後的文章
for new in new_divs:
    n=new.find('div','story-list__text')
    title=n.h2.text.strip()
    date=n.find('time','story-list__time').text.strip()
    content=n.p.text.strip()
    photo_src=new.find('div','story-list__image').img['data-src']
        
    print('標題:',title)
    print('日期:',date)
    print('內文:',content)
    print('圖片連結:',photo_src)
    print()
    txt_list.append([title,date,content,photo_src])
    photo_list.append(photo_src)  
    
## 把需要的文字內容存成csv
# print(txt_list)
# txt_df=pd.DataFrame(txt_list,columns=['標題','日期','內文','圖片網址'])
# print(txt_df)
# txt_df.to_csv('find_'+input_+'_1.csv')

#下載圖片並存檔
print(len(photo_list)) 
for photo in photo_list:
    photo_name=os.path.basename(photo).split('.')[0]+str('.jpg')
    print(photo_name)
    try:
        load_photo=requests.get(photo)
        load_photo.raise_for_status()
        print('圖片下載成功')
        photo_file=open(os.path.join(photo_dir,photo_name),'wb')
        for l in load_photo.iter_content(10240):
            photo_file.write(l)
        photo_file.close()
    except Exception as err:
        print('圖片下載失敗')
print('---所有圖片下載完成---')
    
driver.close()

# %%
# 因為是動態加載的網頁 所以先把全部網頁內容都載完 再一行行寫入csv
from selenium import webdriver
from selenium.webdriver.common.by import By
from selenium.webdriver.chrome.service import Service
from selenium.webdriver.common.keys import Keys
import time
import bs4,requests,os,csv

input_=input('請輸入想查詢的關鍵字:')

# 用selenium找到頁面
url='https://udn.com/news/index'
driver_path=Service('D:/chromedriver.exe')
driver=webdriver.Chrome(service=driver_path)
driver.get(url)
driver.find_element(By.CLASS_NAME,'menu-toggler').click()
# 透過css找到搜尋鍵並按下
find_what=driver.find_element(By.CSS_SELECTOR,"div.input-holder input[type='search']")
find_what.send_keys(input_)  # 送出要搜尋的字串
time.sleep(3)
driver.find_element(By.CLASS_NAME,'btn-search').click()
url_1=driver.current_url  # 找到點入的網址
print(url_1)
time.sleep(3)

# 用bs4找出共幾頁
html=requests.get(url_1)
obj=bs4.BeautifulSoup(html.text,'lxml')

total_num=obj.find('div','search-total').span.text.strip()
print('共',total_num,'篇文章')
total_num=int(int(total_num)/20)
print(total_num)

count_num=0  # 紀錄滑了幾次
add_num=100  # 卷軸要滑的距離

# 執行次數至網頁完全載入 才能一次存爬取內容
for top in range(total_num):
    use_keys=driver.find_element(By.TAG_NAME,'body')
    time.sleep(5)
    count_num+=1
    print('第 %s 次' % count_num)
    add_num+=20  # 因為卷軸會越來越長
    
    # 讓卷軸不段滑的for
    for down in range(0,add_num,2):
        use_keys.send_keys(Keys.PAGE_DOWN)  # 往下快快滑到底 讓網頁動態加載
    time.sleep(5)
    use_keys.send_keys(Keys.HOME)   # 再直接滑到最頂
    new_pega=driver.page_source    # 重新抓取加載後的網頁內容
    new_obj=bs4.BeautifulSoup(new_pega,'lxml')     # 轉成bs4
    
#print(new_obj)
# time.sleep(5)
org_divs=obj.find('div','story-list__holder').find_all('div','story-list__news')
# pp=obj.find('div','story-list__holder').find('section','story-list__holder--append') #.find_all('div','story-list__news  ')
print('原本就在的文章數:',len(org_divs))
new_divs=new_obj.find('div','story-list__holder').find('section','story-list__holder--append').find_all('div','story-list__news')
print('動態加載後文章數:',len(new_divs))

txt_list=[]  # 給需要的文字內容建成表格用
photo_list=[]   # 給圖片用
photo_dir='find_'+input_
file_dir='data_csvs'
    
if os.path.exists(photo_dir)==False:
    os.mkdir(photo_dir)    
if os.path.exists(file_dir)==False:
    os.mkdir(file_dir)

# 原本就在的文章
for org in org_divs:
    s=org.find('div','story-list__text')
    title=s.h2.text.strip()
    date=s.find('time','story-list__time').text.strip()
    content=s.p.text.strip()
    photo_src=org.find('div','story-list__image').img['data-src']

    print('標題:',title)
    print('日期:',date)
    print('內文:',content)  
    print('圖片連結:',photo_src)
    print()
    txt_list.append([title,date,content,photo_src])
    photo_list.append(photo_src)

print(len(txt_list))    
print(len(photo_list))
print('-'*70)

df_file='find_'+input_+'.csv'

# 動態加載後的文章
for new in new_divs:
    n=new.find('div','story-list__text')
    title=n.h2.text.strip()
    date=n.find('time','story-list__time').text.strip()
    content=n.p.text.strip()
    photo_src=new.find('div','story-list__image').img['data-src']
        
    print('標題:',title)
    print('日期:',date)
    print('內文:',content)
    print('圖片連結:',photo_src)
    print()
    txt_list.append([title,date,content,photo_src])
    photo_list.append(photo_src) 

with open(os.path.join(file_dir, df_file),'w',newline='',encoding='utf-8') as csv_file:
    csv_writer=csv.writer(csv_file)
    for row in txt_list:
        try:
            csv_writer.writerow(row)   # 一行行寫入 節省電腦效能 避免內容過多
            print('寫入成功')
        except Exception:
            print('寫入失敗')
            pass
print('====')
print(txt_list)
print(photo_list)

#下載圖片並存檔
print(len(photo_list)) 
for photo in photo_list:
    photo_name=os.path.basename(photo).split('.')[0]+str('.jpg')
    print(photo_name)
    try:
        load_photo=requests.get(photo)
        load_photo.raise_for_status()
        print('圖片下載成功')
        photo_file=open(os.path.join(photo_dir,photo_name),'wb')
        for l in load_photo.iter_content(10240):
            photo_file.write(l)
        photo_file.close()
    except Exception as err:
        print('圖片下載失敗')
print('---所有圖片下載完成---')
    
driver.close()
# Out:
# 請輸入想查詢的關鍵字:七星山
# https://udn.com/search/word/2/%E4%B8%83%E6%98%9F%E5%B1%B1
# 共 293 篇文章
# 14
# 第 1 次
# 第 2 次
# 第 3 次
# 第 4 次
# 第 5 次
# 第 6 次
# 第 7 次
# 第 8 次
# 第 9 次
# 第 10 次
# 第 11 次
# 第 12 次
# 第 13 次
# 第 14 次
# 原本就在的文章數: 20
# 動態加載後文章數: 273
# 標題: 樹之亭、巨石群！春光爛漫「翠山步道至大崙頭山」 乘風堡景觀台展望絕佳
# 日期: 2022-04-12 21:01:06
# 內文: 2022/03/09 週三（2-1 翠山步道→大崙頭山）《春日暢遊翠山步道→小溪頭環狀步道→大崙頭尾山→論劍山→剪刀石山→金面山》【小百岳集起來】#008 內湖大崙頭山 H476m,臺北市加密控制點...
# 圖片連結: https://pgw.udn.com.tw/gw/photo.php?u=https://uc.udn.com.tw/photo/2022/03/17/0/16558302.jpg&s=Y&x=0&y=0&sw=1280&sh=710&exp=3600&w=600
#
# 標題: 訓練心得／陽明山人車分道大體驗
# 日期: 2022-04-06 09:36:39
# 內文: Date：2022/4/5Total distance：4.3 kmTime spent moving：59 min趁著清明連假最後一天，隻身在台北的自由時光，決定來挑戰陽明山上人車分道的健行路線。...
# 圖片連結: https://pgw.udn.com.tw/gw/photo.php?u=https://uc.udn.com.tw/photo/2022/04/06/0/16537194.jpg&s=Y&x=0&y=0&sw=803&sh=535&exp=3600&w=600
#
# 標題: 公車可抵達！台北北投「紗帽山」高CP值步道平易近人　山林有歷史底蘊
# 日期: 2022-04-04 15:30:06
# 內文: 紗帽山交通、停車場、廁所區域、難度、行程規劃懶人包！因外形看似古代官員的烏紗帽而得其名。紗帽山步道全長僅2.2公里，是CP值很高的一條步道，步道皆為石階路線，短短的路程中，蘊藏了豐富的歷史遺跡！沿途...
# 圖片連結: https://pgw.udn.com.tw/gw/photo.php?u=https://uc.udn.com.tw/photo/2022/03/08/0/16520716.jpg&s=Y&x=0&y=0&sw=1280&sh=853&exp=3600&w=600
#
# 標題: A Quest for Spring Flowers: Purple Blossoms Throughout Taipei
# 日期: 2022-03-31 09:49:04
# 內文: 【Author Catherine Shih】【Photographer Geotechnical Engineering Office and Hydraulic Engineering Offi...
# 圖片連結: https://pgw.udn.com.tw/gw/photo.php?u=https://uc.udn.com.tw/photo/2022/03/31/draft/16504414.jpg&s=Y&x=0&y=0&sw=720&sh=480&exp=3600&w=600
#
# 標題: 春の花を求めて 台北に咲く紫色の花
# 日期: 2022-03-31 09:49:04
# 內文: 【文: Catherine Shih】【編集:下山敬之】【写真: 北投区農会、台北市政府工務局水利工程処、台北市政府工務局大地工程処】かつてアメリカのジョンソン大統領夫人であるレディ‧バード‧ジョン...
# 圖片連結: https://pgw.udn.com.tw/gw/photo.php?u=https://uc.udn.com.tw/photo/2022/03/31/draft/16504404.jpg&s=Y&x=0&y=0&sw=720&sh=480&exp=3600&w=600
#
# 標題: 台北／拍照打卡散心好去處 陽明山小油坑、竹子湖
# 日期: 2022-03-18 08:30:00
# 內文: 前山公園繞個小半圈，天氣就變了。臨時決定走陽金公路，到久未謀面的竹子湖、小油坑晃晃。細雨挾帶強風，著實有點兒冷，兩個地方都是拍照打卡便走。說起來，上回造訪都是近廿年前往事，竹子湖變化不小，臨時起意沒...
# 圖片連結: https://pgw.udn.com.tw/gw/photo.php?u=https://uc.udn.com.tw/photo/2022/03
 'https://pgw.udn.com.tw/gw/photo.php?u=https://uc.udn.com.tw/photo/2021/12/21/105/14860202.jpg&s=Y&x=0&y=0&sw=1280&sh=853&exp=3600&w=300', 'https://pgw.udn.com.tw/gw/photo.php?u=https://uc.udn.com.tw/photo/2021/12/16/draft/14800550.jpg&s=Y&x=57&y=0&sw=606&sh=405&exp=3600&w=300', 'https://pgw.udn.com.tw/gw/photo.php?u=https://uc.udn.com.tw/photo/2021/12/14/draft/14784484.jpg&s=Y&x=57&y=0&sw=606&sh=405&exp=3600&w=300', 'https://pgw.udn.com.tw/gw/photo.php?u=https://uc.udn.com.tw/photo/2021/12/14/draft/14780013.jpg&w=300', 'https://pgw.udn.com.tw/gw/photo.php?u=https://uc.udn.com.tw/photo/2021/12/02/0/14677804.jpeg&s=Y&x=0&y=9&sw=798&sh=532&exp=3600&w=300', 'https://pgw.udn.com.tw/gw/pho ...
# 293
# 16558302.jpg
# 圖片下載成功
# 16537194.jpg
# 圖片下載成功
# 16520716.jpg
# 圖片下載成功
# 16504414.jpg
# 圖片下載成功
# 16504404.jpg
# 圖片下載成功
# 16336363.jpg
# 圖片下載成功
# 16265051.jpg
# 圖片下載成功
# 16242691.jpg
# 圖片下載成功
# 16242318.jpg
# 圖片下載成功
# 16132406.jpg
# 圖片下載成功
# 16099543.jpg
# 圖片下載成功
# 16124577.jpg
# 圖片下載成功
# 16104850.jpg
# 圖片下載成功
# 14653104.jpg
# 圖片下載成功
# 15914502.jpg
# 圖片下載成功
# 15542043.jpg
# 圖片下載成功
# 15542043.jpg
# 圖片下載成功
# 15422032.jpg
# 圖片下載成功
# 15263791.jpg
# 圖片下載成功
# 15344606.jpg
# 圖片下載成功
# 15188464.jpg
# 圖片下載成功
# 15224905.jpg
# 圖片下載成功
# 15224734.jpg
# 圖片下載成功
# 15096220.jpg
# 圖片下載成功
# 14961711.jpg
# 圖片下載成功
# 14860202.jpg
# 圖片下載成功
# 14800550.jpg
# 圖片下載成功
# 14784484.jpg
# 圖片下載成功
# 14780013.jpg
# 圖片下載成功
# 14677804.jpg
# 圖片下載成功
# 14646011.jpg
# 圖片下載成功
# noimg_cid12659_6.jpg
# 圖片下載成功
# 14653132.jpg
# 圖片下載成功
# 14653104.jpg
# 圖片下載成功
# 14595500.jpg
# 圖片下載成功
# 14595500.jpg
# 圖片下載成功
# 14550010.jpg
# 圖片下載成功
# 14558922.jpg
# 圖片下載成功
# 14558922.jpg
# 圖片下載成功
# 14528792.jpg
# 圖片下載成功
# 14521689.jpg
# 圖片下載成功
# 14508476.jpg
# 圖片下載成功
# 14508476.jpg
# 圖片下載成功
# 14478701.jpg
# 圖片下載成功
# 14421398.jpg
# 圖片下載成功
# 14379749.jpg
# 圖片下載成功
# 14420411.jpg
# 圖片下載成功
# 14418451.jpg
# 圖片下載成功
# 14411080.jpg
# 圖片下載成功
# 14411080.jpg
# 圖片下載成功
# 14411080.jpg
# 圖片下載成功
# 14402283.jpg
# 圖片下載成功
# 14356352.jpg
# 圖片下載成功
# 14355893.jpg
# 圖片下載成功
# 13185855.jpg
# 圖片下載成功
# 14303399.jpg
# 圖片下載成功
# 14308801.jpg
# 圖片下載成功
# 14308801.jpg
# 圖片下載成功
# 14308703.jpg
# 圖片下載成功
# 14308801.jpg
# 圖片下載成功
# 14245738.jpg
# 圖片下載成功
# 14245737.jpg
# 圖片下載成功
# 14141982.jpg
# 圖片下載成功
# 14140491.jpg
# 圖片下載成功
# 14140487.jpg
# 圖片下載成功
# 14140487.jpg
# 圖片下載成功
# 14136241.jpg
# 圖片下載成功
# 14136240.jpg
# 圖片下載成功
# 14136241.jpg
# 圖片下載成功
# 14136222.jpg
# 圖片下載成功
# 14136220.jpg
# 圖片下載成功
# 14136222.jpg
# 圖片下載成功
# 14060770.jpg
# 圖片下載成功
# 14122679.jpg
# 圖片下載成功
# 14122679.jpg
# 圖片下載成功
# 14122680.jpg
# 圖片下載成功
# 14122627.jpg
# 圖片下載成功
# 14122626.jpg
# 圖片下載成功
# 14122627.jpg
# 圖片下載成功
# 14088235.jpg
# 圖片下載成功
# 14070583.jpg
# 圖片下載成功
# 14070583.jpg
# 圖片下載成功
# 14070583.jpg
# 圖片下載成功
# 14016534.jpg
# 圖片下載成功
# 14057701.jpg
# 圖片下載成功
# 14057698.jpg
# 圖片下載成功
# 14057701.jpg
# 圖片下載成功
# 13997658.jpg
# 圖片下載成功
# 13997654.jpg
# 圖片下載成功
# 13997658.jpg
# 圖片下載成功
# 13954714.jpg
# 圖片下載成功
# 13925710.jpg
# 圖片下載成功
# 13965750.jpg
# 圖片下載成功
# 13965748.jpg
# 圖片下載成功
# 13965750.jpg
# 圖片下載成功
# 13964721.jpg
# 圖片下載成功
# 13964716.jpg
# 圖片下載成功
# 13964721.jpg
# 圖片下載成功
# 13925598.jpg
# 圖片下載成功
# 13896183.jpg
# 圖片下載成功
# 13899615.jpg
# 圖片下載成功
# 13899615.jpg
# 圖片下載成功
# 13899615.jpg
# 圖片下載成功
# 13877777.jpg
# 圖片下載成功
# 13877777.jpg
# 圖片下載成功
# 13877777.jpg
# 圖片下載成功
# 13877506.jpg
# 圖片下載成功
# 13877505.jpg
# 圖片下載成功
# 13877506.jpg
# 圖片下載成功
# 13862722.jpg
# 圖片下載成功
# 13862719.jpg
# 圖片下載成功
# 13862722.jpg
# 圖片下載成功
# 13822682.jpg
# 圖片下載成功
# 13822682.jpg
# 圖片下載成功
# 13822682.jpg
# 圖片下載成功
# 13819990.jpg
# 圖片下載成功
# 13819990.jpg
# 圖片下載成功
# 13819992.jpg
# 圖片下載成功
# 13795730.jpg
# 圖片下載成功
# 13795730.jpg
# 圖片下載成功
# 13795730.jpg
# 圖片下載成功
# 13782080.jpg
# 圖片下載成功
# 13782080.jpg
# 圖片下載成功
# 13782080.jpg
# 圖片下載成功
# 13765542.jpg
# 圖片下載成功
# 13765542.jpg
# 圖片下載成功
# 13765542.jpg
# 圖片下載成功
# 13713583.jpg
# 圖片下載成功
# 13670863.jpg
# 圖片下載成功
# 13736448.jpg
# 圖片下載成功
# 13736447.jpg
# 圖片下載成功
# 13736448.jpg
# 圖片下載成功
# 13734187.jpg
# 圖片下載成功
# 13734187.jpg
# 圖片下載成功
# 13734187.jpg
# 圖片下載成功
# 13733109.jpg
# 圖片下載成功
# 13687510.jpg
# 圖片下載成功
# 13687510.jpg
# 圖片下載成功
# 13687510.jpg
# 圖片下載成功
# 13601538.jpg
# 圖片下載成功
# 13343648.jpg
# 圖片下載成功
# 13311089.jpg
# 圖片下載成功
# 13320258.jpg
# 圖片下載成功
# 13235987.jpg
# 圖片下載成功
# 13227701.jpg
# 圖片下載成功
# 13190967.jpg
# 圖片下載成功
# 13159996.jpg
# 圖片下載成功
# 13116497.jpg
# 圖片下載成功
# 13097452.jpg
# 圖片下載成功
# noimg_cid12659_8.jpg
# 圖片下載成功
# 12959889.jpg
# 圖片下載成功
# 12959889.jpg
# 圖片下載成功
# 12590960.jpg
# 圖片下載成功
# 12553882.jpg
# 圖片下載成功
# 12617923.jpg
# 圖片下載成功
# 12457616.jpg
# 圖片下載成功
# 12411356.jpg
# 圖片下載成功
# 12411356.jpg
# 圖片下載成功
# 12251415.jpg
# 圖片下載成功
# 12130229.jpg
# 圖片下載成功
# 12113454.jpg
# 圖片下載成功
# 12130229.jpg
# 圖片下載成功
# 11997417.jpg
# 圖片下載成功
# 11878732.jpg
# 圖片下載成功
# 11878803.jpg
# 圖片下載成功
# 11879964.jpg
# 圖片下載成功
# 11880014.jpg
# 圖片下載成功
# 11864372.jpg
# 圖片下載成功
# 11803219.jpg
# 圖片下載成功
# 11808331.jpg
# 圖片下載成功
# 11808331.jpg
# 圖片下載成功
# 11785151.jpg
# 圖片下載成功
# 11720583.jpg
# 圖片下載成功
# 11511858.jpg
# 圖片下載成功
# 11449962.jpg
# 圖片下載成功
# 11418064.jpg
# 圖片下載成功
# 11376733.jpg
# 圖片下載成功
# 10340766.jpg
# 圖片下載成功
# 11036847.jpg
# 圖片下載成功
# 10948509.jpg
# 圖片下載成功
# 10934256.jpg
# 圖片下載成功
# 10902941.jpg
# 圖片下載成功
# 10878993.jpg
# 圖片下載成功
# 10806739.jpg
# 圖片下載成功
# 10733635.jpg
# 圖片下載成功
# 10663029.jpg
# 圖片下載成功
# 10281837.jpg
# 圖片下載成功
# 10434014.jpg
# 圖片下載成功
# 10339102.jpg
# 圖片下載成功
# 10340766.jpg
# 圖片下載成功
# 10326092.jpg
# 圖片下載成功
# 10323209.jpg
# 圖片下載成功
# 10247682.jpg
# 圖片下載成功
# 10175823.jpg
# 圖片下載成功
# 10105484.jpg
# 圖片下載成功
# 10036452.jpg
# 圖片下載成功
# 9588634.jpg
# 圖片下載成功
# 9353150.jpg
# 圖片下載成功
# 9215024.jpg
# 圖片下載成功
# 9091168.jpg
# 圖片下載成功
# 9097315.jpg
# 圖片下載成功
# 9074563.jpg
# 圖片下載成功
# 9094746.jpg
# 圖片下載成功
# 9021954.jpg
# 圖片下載成功
# 8962869.jpg
# 圖片下載成功
# 8845416.jpg
# 圖片下載成功
# 8843133.jpg
# 圖片下載成功
# 8805191.jpg
# 圖片下載成功
# 8777457.jpg
# 圖片下載成功
# 8778125.jpg
# 圖片下載成功
# 8732106.jpg
# 圖片下載成功
# 8683775.jpg
# 圖片下載成功
# 8662475.jpg
# 圖片下載成功
# 8635710.jpg
# 圖片下載成功
# 8564187.jpg
# 圖片下載成功
# 8528560.jpg
# 圖片下載成功
# 8528560.jpg
# 圖片下載成功
# 8505828.jpg
# 圖片下載成功
# 8459759.jpg
# 圖片下載成功
# 8393576.jpg
# 圖片下載成功
# 8393543.jpg
# 圖片下載成功
# 8385812.jpg
# 圖片下載成功
# 8354373.jpg
# 圖片下載成功
# noimg_cid6649_2.jpg
# 圖片下載成功
# 8266890.jpg
# 圖片下載成功
# 8159110.jpg
# 圖片下載成功
# 8159355.jpg
# 圖片下載成功
# 8155612.jpg
# 圖片下載成功
# 8078702.jpg
# 圖片下載成功
# 8061424.jpg
# 圖片下載成功
# 7987895.jpg
# 圖片下載成功
# 7985893.jpg
# 圖片下載成功
# 7935706.jpg
# 圖片下載成功
# 7863065.jpg
# 圖片下載成功
# 7810026.jpg
# 圖片下載成功
# 7770636.jpg
# 圖片下載成功
# 7731357.jpg
# 圖片下載成功
# 7726510.jpg
# 圖片下載成功
# 7661286.jpg
# 圖片下載成功
# 7635152.jpg
# 圖片下載成功
# 7616398.jpg
# 圖片下載成功
# 7617679.jpg
# 圖片下載成功
# 7617704.jpg
# 圖片下載成功
# 7577657.jpg
# 圖片下載成功
# 7570286.jpg
# 圖片下載成功
# 7546294.jpg
# 圖片下載成功
# 7415155.jpg
# 圖片下載成功
# 7278300.jpg
# 圖片下載成功
# 7250011.jpg
# 圖片下載成功
# 7248992.jpg
# 圖片下載成功
# 7230338.jpg
# 圖片下載成功
# 7191050.jpg
# 圖片下載成功
# 7140681.jpg
# 圖片下載成功
# 7140347.jpg
# 圖片下載成功
# 7119374.jpg
# 圖片下載成功
# 7113499.jpg
# 圖片下載成功
# 7097368.jpg
# 圖片下載成功
# 7095250.jpg
# 圖片下載成功
# 7043119.jpg
# 圖片下載成功
# 6971040.jpg
# 圖片下載成功
# 6975350.jpg
# 圖片下載成功
# 6961474.jpg
# 圖片下載成功
# 6894236.jpg
# 圖片下載成功
# 6840176.jpg
# 圖片下載成功
# 6831551.jpg
# 圖片下載成功
# 6813217.jpg
# 圖片下載成功
# 6808706.jpg
# 圖片下載成功
# 6799034.jpg
# 圖片下載成功
# 6742891.jpg
# 圖片下載成功
# 6727381.jpg
# 圖片下載成功
# 6705652.jpg
# 圖片下載成功
# 6539301.jpg
# 圖片下載成功
# 6429195.jpg
# 圖片下載成功
# 6419925.jpg
# 圖片下載成功
# 6417607.jpg
# 圖片下載成功
# 6409607.jpg
# 圖片下載成功
# 6399211.jpg
# 圖片下載成功
# 6390334.jpg
# 圖片下載成功
# 6322107.jpg
# 圖片下載成功
# 6292404.jpg
# 圖片下載成功
# 4912493.jpg
# 圖片下載成功
# 4473861.jpg
# 圖片下載成功
# 3842918.jpg
# 圖片下載成功
# 3143324.jpg
# 圖片下載成功
# 2170125.jpg
# 圖片下載成功
# 1544833.jpg
# 圖片下載成功
# noimg_cid1005_5.jpg
# 圖片下載成功
# 648057.jpg
# 圖片下載成功
# 223700.jpg
# 圖片下載成功
# 223256.jpg
# 圖片下載成功
# 214975.jpg
# 圖片下載成功
# 212364.jpg
# 圖片下載成功
# 153795.jpg
# 圖片下載成功
# ---所有圖片下載完成---
